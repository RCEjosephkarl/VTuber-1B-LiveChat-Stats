# %% [markdown]
# # VTuber 1B: Live Chat Analytics
#
# A directory of 32GB unified parquet file were initially preprocessed due to inconsistent

# %%
from pyspark.sql.functions import (
    col, count, avg, max, when, desc, lit,
    approx_count_distinct,
    broadcast,
    sum as spark_sum,
    collect_set,
    size,
    array_distinct,
    flatten,
    collect_list
)

from pyspark.sql import DataFrame
from pyspark.sql.window import Window
from pyspark.sql.functions import rank
from pyspark.sql import Row

import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("VTuber_Analytics")
    .master("local[*]") 
    .config("spark.driver.memory", "10g")
    .config(
        "spark.driver.extraJavaOptions",
        "-XX:+UseG1GC -XX:InitiatingHeapOccupancyPercent=35"
    )
    # Keep chunks small for memory safety
    .config("spark.sql.files.maxPartitionBytes", "67108864")  
    # Arrow makes the Spark -> Pandas transfer 10x to 100x faster.
    .config("spark.sql.execution.arrow.pyspark.enabled", "true")
    .config("spark.sql.shuffle.partitions", "1000")
    # Give the Driver a bit more breathing room when collecting final results for plotting.
    .config("spark.driver.maxResultSize", "2g")
    .getOrCreate()
)

# %%
#Loading datasets
source = '/mnt/processed/private/msds2026/slt9a/unified_chats_2021'
source_2 = '/mnt/processed/private/msds2026/slt9a/channels_2021.csv'
chats = spark.read.parquet(source)
channels = spark.read.csv(
    source_2,
    header=True,
    inferSchema=True)

chats.createOrReplaceTempView('chats')
channels.createOrReplaceTempView('channels')

chats.printSchema()
channels.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- authorChannelId: string (nullable = true)
#  |-- videoId: string (nullable = true)
#  |-- channelId: string (nullable = true)
#  |-- bodyLength: long (nullable = true)
#
# root
#  |-- _c0: integer (nullable = true)
#  |-- channelId: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- englishName: string (nullable = true)
#  |-- affiliation: string (nullable = true)
#  |-- videoCount: integer (nullable = true)

# %%
channels.show(5)
# Out:
# +---+--------------------+----------------------------+--------------------+-----------+----------+
# |_c0|           channelId|                        name|         englishName|affiliation|videoCount|
# +---+--------------------+----------------------------+--------------------+-----------+----------+
# |  0|UCJFZiqLMntJufDCH...|   hololive ホロライブ - ...|Hololive VTuber G...|   Hololive|       509|
# |  1|UCfrWoRGlawPQDQxx...|          hololive Indonesia|  Hololive Indonesia|   Hololive|        69|
# |  2|UCotXwY6s8pWmuWd_...|            hololive English|    Hololive English|   Hololive|        34|
# |  3|UCWsfcksUUpoEvhia...|  holostars ホロスターズ ...|  Holostars Official|   Hololive|       150|
# |  4|UCp6993wxpyDPHUpa...|SoraCh. ときのそらチャンネル|         Tokino Sora|   Hololive|       667|
# +---+--------------------+----------------------------+--------------------+-----------+----------+
# only showing top 5 rows

# %%
def most_channel():
    """
    Which VTuber channels receive the most channels?
    """

    query = """
    SELECT channels.englishName as `English Name`, COUNT(*) as `Total Chats`
    FROM chats
    JOIN channels
    ON chats.channelId = channels.channelId
    GROUP BY channels.englishName
    ORDER BY `Total Chats` DESC
    LIMIT 20;
    """
    
    return spark.sql(query)

# %%
q1 = most_channel()
q1.show()
# Out:
# +----------------+-----------+
# |    English Name|Total Chats|
# +----------------+-----------+
# |    Usada Pekora|   31144439|
# |     Sakura Miko|   18542086|
# |       Gawr Gura|   14632354|
# | Takanashi Kiara|   13825699|
# |   Oozora Subaru|   13272619|
# |   Yukihana Lamy|   12801025|
# |    Uruha Rushia|   12543306|
# |Tsunomaki Watame|   12109778|
# |  Houshou Marine|   11744882|
# |   Watson Amelia|   11272410|
# |          Kuzuha|   11165917|
# |  Inugami Korone|   11019240|
# |    Amane Kanata|    9697269|
# |           Kanae|    9187275|
# | Ninomae Ina’nis|    8529349|
# |Shirakami Fubuki|    8512457|
# |      Kiryu Coco|    8232139|
# |   Mori Calliope|    8223660|
# |     Fuwa Minato|    8119214|
# |  Nekomata Okayu|    8070036|
# +----------------+-----------+

# %%
# Plotly Visualization
fig1 = px.bar(
    q1.toPandas(), 
    x='English Name', 
    y='Total Chats', 
    title='Total Message Volume by Affiliation',
    labels={'English Name': 'VTuber', 'Total Chats': 'Overall Chats'},
    color='English Name',
    template='plotly_dark'
)
fig1.show()

# %%
def mo_stream_chats():
    """
    How many stream chats done per month of the year 2021?
    """

    query = """
    SELECT 
        DATE_FORMAT(timestamp, 'yyyy-MM') AS `year-month`,
        COUNT(*) AS total_chats
    FROM chats
    GROUP BY DATE_FORMAT(timestamp, 'yyyy-MM')
    ORDER BY `year-month`;
    """
    return spark.sql(query)

# %%
q2 = mo_stream_chats()
q2.show()
# Out:
# +----------+-----------+
# |year-month|total_chats|
# +----------+-----------+
# |   2021-01|    1998144|
# |   2021-02|   30707138|
# |   2021-03|   67126793|
# |   2021-04|   63446229|
# |   2021-05|   75898905|
# |   2021-06|   75388311|
# |   2021-07|   80829747|
# |   2021-08|   99281411|
# |   2021-09|   87760727|
# |   2021-10|   83370517|
# |   2021-11|   81942259|
# |   2021-12|     591577|
# +----------+-----------+

# %%
# Reverse the dataframe so the highest value is at the top of the chart
fig2 = px.bar(
    q2.toPandas(), 
    x='year-month', 
    y='total_chats', 
    orientation='v',
    title='Monthly VTuber Chat Activity',
    template='plotly_dark'
)
fig2.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# 1. Ensure you have the Pandas DataFrame from your Spark query
q2_df = q2.toPandas()

# 2. Set the visual style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))

# 3. Create the Vertical Bar Plot
# We use a color palette like 'viridis' or 'Blues_d' for a professional look
bar_plot = sns.barplot(
    data=q2_df, 
    x='year-month',
    y='total_chats',
    palette='viridis'
)

# 4. Format the Y-Axis for Big Data (Millions)
# This converts 1,000,000 to '1M'
def millions(x, pos):
    return f'${x*1e-6:,.0f}$M'

bar_plot.yaxis.set_major_formatter(ticker.FuncFormatter(millions))

# 5. Add Data Labels on top of each bar
# This makes the static plot much easier to read at a glance
for p in bar_plot.patches:
    bar_plot.annotate(
        f'${p.get_height()*1e-6:.1f}$M', 
        (p.get_x() + p.get_width() / 2., p.get_height()), 
        ha='center', va='center', 
        xytext=(0, 9), 
        textcoords='offset points',
        fontsize=10,
        fontweight='bold'
    )

# 6. Final Aesthetic Touches
plt.title('Total VTuber Live Chat Volume by Month (2021)', fontsize=16, pad=20)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Chats Sent', fontsize=12)
plt.xticks(rotation=45)

# 7. Clean display
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10866/2173068415.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Spark does the heavy lifting: Filter for 2021 and group by day
def daily_chats():
    """
    How does chat frequency change over time?
    """
    query = """
    SELECT DATE(timestamp) AS chat_date,
           COUNT(*) AS daily_chats
    FROM chats
    GROUP BY DATE(timestamp)
    ORDER BY chat_date;
    """
    return spark.sql(query)

# Safely collect the ~365 rows to the Driver's RAM
q3_df = daily_chats().toPandas()


# Set the theme for a professional look
sns.set_theme(style="whitegrid")

plt.figure(figsize=(15, 6))

# Create the line plot
line_plot = sns.lineplot(data=q3_df, x='chat_date', y='daily_chats', color='royalblue', linewidth=3)

# Improve Date Formatting on X-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d')) # Shows "Jan 01"
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())          # Tick marks at every month

plt.title('Daily Total Chat Frequency (2021)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Messages Sent', fontsize=12)

# Rotate labels so they don't overlap
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# 1. Spark does the heavy lifting: Find Top 10, Join, and Group

def vtuber_daily():
    """doctring"""
    
    query = """
    -- Step A: Find the Top 10 Channels by total chat volume
    WITH Top10Channels AS (
        SELECT channelId, COUNT(*) as total_chats
        FROM chats
        GROUP BY channelId
        ORDER BY total_chats DESC
        LIMIT 10
    )
    -- Step B: Join that top 10 list with the main data and channels table
    SELECT DATE(c.timestamp) AS chat_date,
           ch.englishName AS vtuber_name,
           COUNT(*) AS daily_chats
    FROM chats c
    JOIN channels ch ON c.channelId = ch.channelId
    JOIN Top10Channels t ON c.channelId = t.channelId
    GROUP BY DATE(c.timestamp), ch.englishName
    ORDER BY chat_date;
    """
    return spark.sql(query)


# 2. Collect the summarized data (roughly 365 days * 10 VTubers = ~3,650 rows)
q3_modified_df = vtuber_daily().toPandas()

# 3. Build the Plotly Line Chart
fig = px.line(
    q3_modified_df,
    x='chat_date',
    y='daily_chats',
    color='vtuber_name',
    title='Daily VTuber Chat Volume (Top 10) with Interactive Time Slider',
    width=1500,
    height=600
)

# 4. Add back your Range Slider and Quick-Select Buttons
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=7, label="1 Week", step="day", stepmode="backward"),
            dict(count=1, label="1 Month", step="month", stepmode="backward"),
            dict(count=3, label="3 Months", step="month", stepmode="backward"),
            dict(step="all", label="Entire 2021")
        ])
    )
)

# 5. Clean up the Y-axis
fig.update_yaxes(rangemode="tozero")

# 6. Display in Colab
display(fig)

# %% [markdown]
# Just a preview of the table from that graph

# %%
vtuber_daily().show(50)
# Out:
# +----------+----------------+-----------+
# | chat_date|     vtuber_name|daily_chats|
# +----------+----------------+-----------+
# |2021-01-15|   Oozora Subaru|       2015|
# |2021-01-16|   Watson Amelia|      28653|
# |2021-01-16| Takanashi Kiara|      64832|
# |2021-01-17|    Usada Pekora|     251729|
# |2021-01-17|       Gawr Gura|      17713|
# |2021-01-18|   Watson Amelia|      15517|
# |2021-01-18|Tsunomaki Watame|      53645|
# |2021-01-18|       Gawr Gura|     154646|
# |2021-01-18|    Usada Pekora|      12474|
# |2021-01-18| Takanashi Kiara|      43202|
# |2021-01-19| Takanashi Kiara|      23299|
# |2021-01-21|    Usada Pekora|      50936|
# |2021-01-22|  Houshou Marine|      31455|
# |2021-01-22|   Watson Amelia|       9709|
# |2021-01-22|    Usada Pekora|      33095|
# |2021-01-22|    Uruha Rushia|      63625|
# |2021-01-23| Takanashi Kiara|      31974|
# |2021-01-23|       Gawr Gura|     131495|
# |2021-01-25| Takanashi Kiara|       9697|
# |2021-01-25|  Houshou Marine|      26947|
# |2021-01-25|     Sakura Miko|      46128|
# |2021-02-03| Takanashi Kiara|      29417|
# |2021-02-08|  Houshou Marine|      31125|
# |2021-02-09|  Houshou Marine|      43266|
# |2021-02-10|  Houshou Marine|      79078|
# |2021-02-10| Takanashi Kiara|       1096|
# |2021-02-10|    Usada Pekora|     116226|
# |2021-02-10|   Oozora Subaru|      27121|
# |2021-02-10|     Sakura Miko|      26837|
# |2021-02-10|Tsunomaki Watame|      37848|
# |2021-02-11|  Houshou Marine|      51616|
# |2021-02-11|    Uruha Rushia|      49172|
# |2021-02-11|     Sakura Miko|     131089|
# |2021-02-11|   Watson Amelia|      63898|
# |2021-02-11|   Yukihana Lamy|         90|
# |2021-02-11| Takanashi Kiara|      61308|
# |2021-02-11|Tsunomaki Watame|      49877|
# |2021-02-11|       Gawr Gura|      46410|
# |2021-02-11|    Usada Pekora|     112310|
# |2021-02-12|   Yukihana Lamy|      23253|
# |2021-02-12|    Usada Pekora|      60847|
# |2021-02-12| Takanashi Kiara|      56965|
# |2021-02-12|Tsunomaki Watame|      45795|
# |2021-02-12|    Uruha Rushia|      85263|
# |2021-02-12|   Oozora Subaru|      60698|
# |2021-02-12|     Sakura Miko|      25820|
# |2021-02-12|   Watson Amelia|     104160|
# |2021-02-13|  Houshou Marine|      60766|
# |2021-02-13|   Oozora Subaru|      68886|
# |2021-02-13| Takanashi Kiara|      60635|
# +----------+----------------+-----------+
# only showing top 50 rows

# %%
# Are longer chats more common in some streams or channels?

def long_chat():
    """
    Are longer chats more common in some streams or channels?
    """
    query = """
    SELECT ch.englishName AS `English Name`,
        AVG(c.bodyLength) AS avg_chat_length,
        COUNT(*) AS total_chats
    FROM chats c
    JOIN channels ch
    ON c.channelId = ch.channelId
    GROUP BY ch.englishName
    HAVING total_chats > 5000  -- Filters out low-chat anomalies
    ORDER BY avg_chat_length DESC;
    """
    return spark.sql(query)

# %%
# 1. Execute the query and convert to Pandas
df_pd = long_chat().toPandas()

# 2. Generate Scatter Plot
fig1 = px.scatter(
    df_pd, 
    x='total_chats', 
    y='avg_chat_length', 
    hover_name='English Name',          # Shows the VTuber name when hovering over a dot
    size='total_chats',                 # Optional: Makes dots bigger for higher chat volumes
    title='Average Chat Length vs. Total Chat Volume per VTuber',
    labels={
        'total_chats': 'Total Chat Volume', 
        'avg_chat_length': 'Average Chat Length (characters)'
    },
    template='plotly_dark',              # Optional: Gives it a sleek dark theme
    width=1600,
    height=900
)

# Optional: Add a trendline to see if bigger streams generally have shorter chats
fig1.update_traces(marker=dict(opacity=0.7)) 

fig1.show()

# %%
long_chat().show(20, truncate=False)
# Out:
# +---------------+------------------+-----------+
# |English Name   |avg_chat_length   |total_chats|
# +---------------+------------------+-----------+
# |Walfie         |34.25545092586741 |15823      |
# |Europa         |30.256508875739645|6760       |
# |Ushio Ebi      |27.13420306398048 |222521     |
# |Pipkin Pippa   |26.941926459667343|335299     |
# |Orla Gan Ceann |26.629163400680884|85477      |
# |Kaga Oren      |25.966904345486345|22299      |
# |Tsurugi Nen    |25.54158964879852 |7033       |
# |Cecile         |25.038280616382806|24660      |
# |Yazaki Kallin  |25.01006081654584 |128419     |
# |FruFru VTubers |24.907278733340927|17558      |
# |Jaret Fajrianto|24.826221939181657|12562      |
# |Shee Icho      |24.79529848937717 |61895      |
# |Fujikura Uruka |24.738833804454725|161671     |
# |Tetsuya Kazune |24.548014359434596|26742      |
# |Mana Renewal   |24.499610776369554|360975     |
# |Kyria          |24.15782109345106 |175097     |
# |Rinkou Ashelia |24.148406902441177|135836     |
# |Kitsui Akira   |23.969055168040583|15770      |
# |Reina Sun      |23.627458623838905|179572     |
# |Vihaan         |23.592083562396923|18190      |
# +---------------+------------------+-----------+
# only showing top 20 rows

# %%
# Querying Affiliations
def affiliations():
    """
    Just Getting list of affiliation
    """

    query = """
    SELECT DISTINCT(affiliation)
    FROM channels;
    """
    return spark.sql(query)

# %%
affiliations().toPandas()
# Out:
#              affiliation
# 0              Snacknili
# 1                 H.Live
# 2                 Axel-V
# 3                 WACTOR
# 4            Shinsougumi
# 5                   VSpo
# 6             Riot Music
# 7             Masquerade
# 8                Emoechi
# 9                  ViViD
# 10                  VOMS
# 11         Phase Connect
# 12         Cloud Horizon
# 13    Unreal Night Girls
# 14             Nijisanji
# 15             Neo-Porte
# 16             MyHolo TV
# 17             idol Corp
# 18                 MAHA5
# 19        Pixela Project
# 20     Aogiri Highschool
# 21          Independents
# 22     Production Kawaii
# 23                774inc
# 24              Aetheria
# 25     WAK Entertainment
# 26               NIJIGEN
# 27                 ReAcT
# 28          Atelier Live
# 29        KEMOMIMI REFLE
# 30            SquareLive
# 31               GuildCQ
# 32              Nori Pro
# 33  V Dimension.Creators
# 34               Polygon
# 35                 .LIVE
# 36              Hololive
# 37           Yuni Create
# 38               Iridori
# 39                 PRISM
# 40            ReMemories
# 41         Eilene Family
# 42             Chukorara
# 43               AkioAIR
# 44                VShojo
# 45         Sleep Monster
# 46               Marbl_s
# 47          KAWAII MUSIC
# 48   Twitch Independents
# 49                ProPro
# 50           KAMITSUBAKI
# 51    Hoshimeguri Gakuen
# 52        La Peche Party
# 53        Kizuna Ai Inc.
# 54         Pink Punk Pro
# 55          Yume Reality
# 56             VOICE-ORE
# 57            X enc'ount
# 58             Tsunderia
# 59        Kemono Friends

# %% [markdown]
# ### Basic Aggregation: Total Message Volume by Affiliation
#
# Business Objective: Get a __macro-level__ view of which VTuber agencies drive the highest total volume of chat interactions across all their talents.
#
# Concepts: `INNER JOIN`, `COUNT`, `GROUP BY`, `ORDER BY`

# %%
def x5():
    query = """
    SELECT 
    ch.affiliation, 
    COUNT(1) AS total_messages
    FROM chats c
    JOIN channels ch ON c.channelId = ch.channelId
    WHERE ch.affiliation IS NOT NULL
    GROUP BY ch.affiliation
    ORDER BY total_messages DESC
    LIMIT 20;
    """
    return spark.sql(query)

# %%
# 1. Execute your function and store the Pandas DataFrame
df_x5 = x5().toPandas()

# 2. Generate the interactive bar chart
fig1 = px.bar(
    df_x5,
    x='affiliation',
    y='total_messages',
    title='Total Message Volume by Affiliation',
    labels={
        'affiliation': 'VTuber Agency', 
        'total_messages': 'Total Chat Messages'
    },
    color='affiliation',            # Auto-assigns different colors per agency
    template='plotly_dark',         # Sleek dark mode to match standard notebook themes
    width=1600,
    height=900
)

# Optional: Add abbreviated text labels directly on top of the bars (e.g., 2.5M)
fig1.update_traces(texttemplate='%{y:.2s}', textposition='outside')

fig1.show()

# %%
x5().show()
# Out:
# +-----------------+--------------+
# |      affiliation|total_messages|
# +-----------------+--------------+
# |         Hololive|     343361344|
# |        Nijisanji|     228736400|
# |     Independents|      55363350|
# |           774inc|      29060655|
# |            .LIVE|      13396002|
# |         Nori Pro|      10915298|
# |             VSpo|       8898313|
# |           WACTOR|       7878021|
# |            ReAcT|       4510546|
# |        Neo-Porte|       4062434|
# |             VOMS|       3787485|
# |           VShojo|       3739429|
# |            PRISM|       3482182|
# |       Masquerade|       3187352|
# |           ProPro|       2396761|
# |       SquareLive|       2278501|
# |            ViViD|       1731292|
# |Production Kawaii|       1564174|
# |          GuildCQ|       1423863|
# |Aogiri Highschool|       1177198|
# +-----------------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### Basic Filtering: Top 10 Most Active VTubers in a Specific Agency
#
# Business Objective: Drill down into a specific agency (e.g., **Nijisanji**) to identify their top performers based purely on standard text chat engagement.
#
# Concepts: `WHERE` filtering with multiple conditions

# %%
def x6_for_dropdown():
    query = """
    SELECT
        ch.englishName,
        ch.affiliation,
        COUNT(c.channelId) as count
    FROM
        chats c
    JOIN
        channels ch ON c.channelId = ch.channelId
    WHERE 
        ch.affiliation IN ('Nijisanji', 'Hololive', '774inc', 'Nori Pro', 'Independents')
    GROUP BY
        ch.englishName, ch.affiliation
    ORDER BY
        count DESC
    """
    return spark.sql(query)

# %%
# 1. Fetch data
df = x6_for_dropdown().toPandas()
affiliations = df['affiliation'].unique()

# Define a color palette (using a qualitative sequence)
palette = px.colors.qualitative.Vivid 

fig = go.Figure()

# 2. Add a trace for each affiliation
for i, aff in enumerate(affiliations):
    # Filter for top 10 of THIS specific agency
    aff_df = df[df['affiliation'] == aff].head(10)
    
    # Assign a unique color from the palette to each agency trace
    trace_color = palette[i % len(palette)]
    
    fig.add_trace(
        go.Bar(
            x=aff_df['englishName'],
            y=aff_df['count'],
            name=aff,
            marker_color=trace_color, # Applying the palette
            visible=False 
        )
    )

# 3. Make the first one visible initially
if len(fig.data) > 0:
    fig.data[0].visible = True

# 4. Define the dropdown buttons
buttons = []
for i, aff in enumerate(affiliations):
    visibility = [False] * len(affiliations)
    visibility[i] = True
    
    button = dict(
        label=aff,
        method="update",
        args=[{"visible": visibility},
              {"title": f"Engagement Leaderboard: {aff}"}] # Updated Title logic
    )
    buttons.append(button)

# 5. Add the menu to the layout with Top-Right positioning
fig.update_layout(
    updatemenus=[dict(
        active=0,
        buttons=buttons,
        direction="down",
        pad={"r": 10, "t": 10},
        showactive=True,
        # Positioning: Top Right
        x=1.0,           
        xanchor="right", 
        y=1.15,          
        yanchor="top"
    )],
    title={
        'text': f"Engagement Leaderboard: {affiliations[0]}",
        'y': 0.9,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    template='plotly_dark',
    xaxis_title="VTuber Name",
    yaxis_title="Total Message Count",
    margin=dict(t=100) # Add top margin to prevent title/menu overlap
)

fig.show()

# %%
x6().show()
# Out:
# +----------------+--------+
# |     englishName|   count|
# +----------------+--------+
# |          Kuzuha|11165917|
# |           Kanae| 9187275|
# |     Fuwa Minato| 8119214|
# |         Ibrahim| 8037235|
# |   Yuuki Chihiro| 5875431|
# |Furen E Lustario| 5196631|
# |     Nui Sociere| 5137712|
# |   Kagami Hayato| 4745107|
# |   Elira Pendora| 4514083|
# |    Leos Vincent| 4453654|
# +----------------+--------+

# %% [markdown]
# ### Date Truncation: Daily Chat Volume Comparison Among Major Agencies
#
# Business Objective: Compare the daily engagement trends of the major agencies side-by-side to see who "won" specific days (e.g., during major 3D live events or agency-wide tournaments).
#
# Concepts: `TO_DATE()`, Time-based grouping across multiple dimensions

# %%
def x7():
    """ docstring hehe"""
    
    query = """
    SELECT 
        ch.affiliation, 
        TO_DATE(c.timestamp) AS stream_date,
        COUNT(1) AS daily_messages
    FROM
        chats c
    JOIN
        channels ch ON c.channelId = ch.ChannelId
    WHERE
        ch.affiliation IN ('Nijisanji', 'Hololive', '774inc', 'Nori Pro', 'Independents')
    GROUP BY
        ch.affiliation, 
        TO_DATE(c.timestamp)
    ORDER BY
        stream_date ASC, 
        daily_messages DESC;
    """
    return spark.sql(query)

# %%
import plotly.express as px

# 1. Fetch the time-series data
df_x7 = x7().toPandas()

# 2. Create the interactive line plot
fig = px.line(
    df_x7, 
    x='stream_date', 
    y='daily_messages', 
    color='affiliation',
    title='Daily Chat Volume Trends by Affiliation',
    labels={
        'stream_date': 'Date', 
        'daily_messages': 'Total Messages', 
        'affiliation': 'Agency'
    },
    template='plotly_dark',
    color_discrete_sequence=px.colors.qualitative.Vivid
)

# 3. Add interactivity features
fig.update_xaxes(
    rangeslider_visible=True, # Adds the slider at the bottom
    rangeselector=dict(       # Adds quick-buttons for 7d, 1m, etc.
        buttons=list([
            dict(count=7, label="1w", step="day", stepmode="backward"),
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(step="all")
        ])
    )
)

# Improve hover experience (shows all agencies for a specific date)
fig.update_layout(hovermode="x unified")

fig.show()

# %%
x7().show()
# Out:
# +-----------+-----------+--------------+
# |affiliation|stream_date|daily_messages|
# +-----------+-----------+--------------+
# |   Hololive| 2021-01-15|         25083|
# |   Hololive| 2021-01-16|        220849|
# |   Hololive| 2021-01-17|        501428|
# |   Hololive| 2021-01-18|        362902|
# |   Hololive| 2021-01-19|         67864|
# |   Hololive| 2021-01-20|         15177|
# |   Hololive| 2021-01-21|         50936|
# |   Hololive| 2021-01-22|        315740|
# |   Hololive| 2021-01-23|        310307|
# |   Hololive| 2021-01-24|         22888|
# |   Hololive| 2021-01-25|        104970|
# |   Hololive| 2021-02-01|         53981|
# |   Hololive| 2021-02-02|          8859|
# |   Hololive| 2021-02-03|         39834|
# |   Hololive| 2021-02-04|         12087|
# |   Hololive| 2021-02-07|        106372|
# |   Hololive| 2021-02-08|         75385|
# |   Hololive| 2021-02-09|         50776|
# |   Hololive| 2021-02-10|        636932|
# |   Hololive| 2021-02-11|       1326800|
# +-----------+-----------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### Common Table Expressions (CTE): Unique Audience Size per Affiliation
#
# Business Objective: Message volume can be skewed by chat spammers. This query calculates the unique number of individual viewers chatting within each agency's ecosystem.
#
# Concepts: `WITH (CTE), COUNT(DISTINCT ...)`

# %%
def x8():
    query = """
    WITH AgencyAudience AS (
        SELECT 
            ch.affiliation, 
            c.authorChannelId
        FROM
            chats c
        JOIN
            channels ch ON c.channelId = ch.channelId
        WHERE
            ch.affiliation IS NOT NULL
        -- Grouping first to reduce the size of the dataset before the distinct count
        GROUP BY
            ch.affiliation,
            c.authorChannelId
    )
    SELECT 
        affiliation,
        COUNT(DISTINCT authorChannelId) AS unique_chatters
    FROM
        AgencyAudience
    GROUP BY
        affiliation
    ORDER BY
        unique_chatters DESC;
    """
    return spark.sql(query)

# %%
# 1. Execute the query and convert to Pandas
df_x8 = x8().toPandas()

# 2. Generate the interactive Pie/Donut Chart
fig = px.pie(
    df_x8, 
    values='unique_chatters', 
    names='affiliation', 
    title='Audience Reach: Unique Chatters per Affiliation',
    hole=0.4,                                 # Creates the "Donut" look for better readability
    color_discrete_sequence=px.colors.qualitative.Pastel,
    template='plotly_dark'
)

# 3. Enhance interactivity and labels
fig.update_traces(
    textposition='inside', 
    textinfo='percent+label',                 # Shows both the name and the % inside the slice
    hoverinfo='label+value+percent',          # Shows the exact count on hover
    marker=dict(line=dict(color='#000000', width=2)) # Adds a clean border between slices
)

fig.update_layout(
    legend_title="Agencies",
    font=dict(size=14)
)

fig.show()

# %%
x8().show(10)
# Out:
# +------------+---------------+
# | affiliation|unique_chatters|
# +------------+---------------+
# |    Hololive|        2342738|
# |   Nijisanji|        1182972|
# |Independents|        1036025|
# |      774inc|         161602|
# |   Neo-Porte|         154483|
# |        VSpo|         152660|
# |      VShojo|         140971|
# |    Nori Pro|         108887|
# |        VOMS|          96529|
# |      WACTOR|          84959|
# +------------+---------------+
# only showing top 10 rows

# %% [markdown]
# ### Window Functions: Ranking Top VTubers Within Each Affiliation
#
# Business Objective: Create an internal leaderboard for every agency. Instead of comparing an indie to a massive Hololive star, this ranks talents strictly against their direct agency peers.
#
# Concepts: `RANK() OVER(PARTITION BY ... ORDER BY ...)`

# %%
def x9():
    """ docstring """
    query = """
    WITH AgencyStats AS (
        SELECT 
            ch.affiliation,
            ch.englishName,
            COUNT(1) AS chat_volume
        FROM 
            chats c 
        JOIN 
            channels ch ON c.channelId = ch.channelId
        WHERE 
            ch.affiliation IS NOT NULL
        GROUP BY 
            ch.affiliation, 
            ch.englishName
    )
    SELECT 
        affiliation, 
        englishName, 
        chat_volume,
        RANK() OVER (PARTITION BY affiliation ORDER BY chat_volume DESC) as rank_in_agency
    FROM
        AgencyStats
    ORDER BY
        affiliation ASC, 
        rank_in_agency ASC;
    """

    return spark.sql(query)

# %%
# 1. Fetch data
df = x9().toPandas()

# Get unique affiliations
affiliations = df['affiliation'].dropna().unique()

# Optional: Limit to top 20 ranks per agency so the charts don't become unreadable
df_top = df[df['rank_in_agency'] <= 20]

# 2. Initialize a 1x2 Subplot
fig = make_subplots(
    rows=1, cols=2, 
    subplot_titles=("Top VTubers by Chat Volume", "Volume Distribution Curve (Power Law)"),
    horizontal_spacing=0.1
)

# 3. Add traces for BOTH plots for EVERY affiliation
for i, aff in enumerate(affiliations):
    aff_df = df_top[df_top['affiliation'] == aff]
    
    # Only the first agency should be visible on load
    is_visible = (i == 0)
    
    # --- Left Plot: Bar Chart ---
    fig.add_trace(
        go.Bar(
            x=aff_df['englishName'],
            y=aff_df['chat_volume'],
            name=f"{aff} (Bar)",
            marker_color='#636EFA', # Plotly standard blue
            visible=is_visible,
            showlegend=False
        ),
        row=1, col=1
    )
    
    # --- Right Plot: Line Plot ---
    # Plotting Rank vs Volume to show how "top heavy" an agency is
    fig.add_trace(
        go.Scatter(
            x=aff_df['rank_in_agency'],
            y=aff_df['chat_volume'],
            mode='lines+markers',
            name=f"{aff} (Line)",
            line=dict(color='#00CC96', width=4), # Plotly standard teal
            marker=dict(size=8),
            visible=is_visible,
            showlegend=False
        ),
        row=1, col=2
    )

# 4. Define the Dropdown logic
buttons = []
num_traces_per_aff = 2 # 1 bar trace + 1 line trace per agency

for i, aff in enumerate(affiliations):
    # Create a boolean list where everything is False by default
    visibility = [False] * (len(affiliations) * num_traces_per_aff)
    
    # Turn on the two traces (Bar and Line) corresponding to this specific agency
    visibility[i * 2] = True
    visibility[i * 2 + 1] = True
    
    button = dict(
        label=aff,
        method="update",
        args=[
            {"visible": visibility},
            {"title": f"Engagement Dashboard: {aff}"}
        ]
    )
    buttons.append(button)

# 5. Apply the Layout (1600x900 resolution & Dropdown positioning)
fig.update_layout(
    title={
        'text': f"Engagement Dashboard: {affiliations[0]}",
        'y': 0.95,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    width=1600,
    height=900,
    template='plotly_dark',
    updatemenus=[dict(
        active=0,
        buttons=buttons,
        direction="down",
        pad={"r": 10, "t": 10},
        showactive=True,
        x=1.0,           # Top Right placement
        xanchor="right", 
        y=1.1,          
        yanchor="top"
    )]
)

# Axis Labels
fig.update_xaxes(title_text="VTuber Name", row=1, col=1, tickangle=-45)
fig.update_yaxes(title_text="Total Chat Volume", row=1, col=1)

fig.update_xaxes(title_text="Agency Rank", row=1, col=2)
fig.update_yaxes(title_text="Total Chat Volume", row=1, col=2)

fig.show()

# %%
x9().show()
# Out:
# +-----------+-------------------+-----------+--------------+
# |affiliation|        englishName|chat_volume|rank_in_agency|
# +-----------+-------------------+-----------+--------------+
# |      .LIVE|    Kakyouin Chieri|    4627495|             1|
# |      .LIVE|        Kagura Suzu|    2257923|             2|
# |      .LIVE|         Carro Pino|    1393998|             3|
# |      .LIVE|        Yamato Iori|    1355469|             4|
# |      .LIVE|      Mokota Mememe|     815283|             5|
# |      .LIVE| Dennou Shojo Shiro|     715679|             6|
# |      .LIVE|     Rurun Rururica|     576600|             7|
# |      .LIVE|     Yaezawa Natori|     447017|             8|
# |      .LIVE|   Nanahoshi Milily|     399271|             9|
# |      .LIVE|             Rikumu|     396700|            10|
# |      .LIVE|    Kitakami Futaba|     235566|            11|
# |      .LIVE|       Kongou Iroha|      88512|            12|
# |      .LIVE|         Merry Milk|      51470|            13|
# |      .LIVE|           Baacharu|      35019|            14|
# |     774inc|         Suou Patra|    4822220|             1|
# |     774inc|       Inaba Haneru|    4270459|             2|
# |     774inc|         Komori Met|    1786575|             3|
# |     774inc|       Souya Ichika|    1707266|             4|
# |     774inc|       Saionji Mary|    1392980|             5|
# |     774inc|Shimamura Charlotte|    1342147|             6|
# +-----------+-------------------+-----------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### Window Functions: Cumulative Engagement Growth by Affiliation
#
# Business Objective: Visualize the compounding growth of agencies over time by tracking their running total of chat messages day over day.
#
# Concepts: `SUM() OVER(... ROWS BETWEEN UNBOUNDED PRECEDING...)`

# %%
def x10():
    """ dock istring """
    query = """
    WITH DailyAgencyVolume AS (
        SELECT 
            ch.affiliation, 
            TO_DATE(c.timestamp) AS chat_date, 
            COUNT(1) as daily_volume
        FROM 
            chats c 
        JOIN 
            channels ch ON c.channelId = ch.channelId
        WHERE 
            ch.affiliation IS NOT NULL
        GROUP BY 
            ch.affiliation,
            TO_DATE(c.timestamp)
    )
    SELECT 
        affiliation, 
        chat_date, 
        daily_volume,
        SUM(daily_volume) OVER (
            PARTITION BY affiliation 
            ORDER BY chat_date 
            ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
        ) as cumulative_volume
    FROM 
        DailyAgencyVolume
    ORDER BY 
        affiliation, 
        chat_date;
    """

    return spark.sql(query)

# %%
# 1. Execute the query and convert to Pandas
df = x10().toPandas()

# 2. Get the unique affiliations to populate our dropdown
affiliations = df['affiliation'].dropna().unique()

fig = go.Figure()

# 3. Add a line trace for each affiliation
for i, aff in enumerate(affiliations):
    # Filter data for the specific agency
    aff_df = df[df['affiliation'] == aff]
    
    fig.add_trace(
        go.Scatter(
            x=aff_df['chat_date'],
            y=aff_df['cumulative_volume'],
            mode='lines',
            name=aff,
            line=dict(width=3),
            visible=(i == 0) # Only the first agency is visible by default
        )
    )

# 4. Create the Dropdown Menu Buttons
buttons = []
for i, aff in enumerate(affiliations):
    # Create a boolean list: True for the current trace, False for all others
    visibility = [False] * len(affiliations)
    visibility[i] = True
    
    button = dict(
        label=aff,
        method="update",
        args=[
            {"visible": visibility}, # Toggles trace visibility
            {"title": f"Cumulative Chat Volume Growth: {aff}"} # Updates title dynamically
        ]
    )
    buttons.append(button)

# 5. Configure Layout and Dropdown Placement
fig.update_layout(
    title=f"Cumulative Chat Volume Growth: {affiliations[0]}",
    xaxis_title="Date",
    yaxis_title="Cumulative Messages",
    template='plotly_dark',
    updatemenus=[dict(
        active=0,
        buttons=buttons,
        direction="down",
        pad={"r": 10, "t": 10},
        showactive=True,
        x=0.05,          # Top Left positioning for the dropdown
        xanchor="left",
        y=1.15,
        yanchor="top"
    )]
)

fig.show()

# %%
x10().show()
# Out:
# +-----------+----------+------------+-----------------+
# |affiliation| chat_date|daily_volume|cumulative_volume|
# +-----------+----------+------------+-----------------+
# |      .LIVE|2021-02-18|       25477|            25477|
# |      .LIVE|2021-02-19|       50790|            76267|
# |      .LIVE|2021-02-20|        6980|            83247|
# |      .LIVE|2021-02-21|        2897|            86144|
# |      .LIVE|2021-02-22|       14046|           100190|
# |      .LIVE|2021-02-23|       11693|           111883|
# |      .LIVE|2021-02-24|       67185|           179068|
# |      .LIVE|2021-02-25|       54890|           233958|
# |      .LIVE|2021-02-26|       18275|           252233|
# |      .LIVE|2021-02-27|       69066|           321299|
# |      .LIVE|2021-02-28|       65023|           386322|
# |      .LIVE|2021-03-01|       15150|           401472|
# |      .LIVE|2021-03-02|       40705|           442177|
# |      .LIVE|2021-03-03|       23383|           465560|
# |      .LIVE|2021-03-04|       24106|           489666|
# |      .LIVE|2021-03-05|       16380|           506046|
# |      .LIVE|2021-03-06|       83357|           589403|
# |      .LIVE|2021-03-07|       55227|           644630|
# |      .LIVE|2021-03-08|       45246|           689876|
# |      .LIVE|2021-03-09|       58223|           748099|
# +-----------+----------+------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### Time-Series: 7-Day Moving Average of Unique Active Chatters per Agency
#
# Business Objective: Smooth out the volatility of single-day massive events to understand the true underlying **daily active user** (DAU) base supporting each affiliation over time.
#
# Concepts: Time-series smoothing, Window Functions with `ROWS BETWEEN`

# %%
def x11():
    """ dcstrng """
    query = """
    WITH DailyActiveChatters AS (
    SELECT 
        ch.affiliation, 
        TO_DATE(c.timestamp) AS chat_date, 
        COUNT(DISTINCT c.authorChannelId) as daily_active_users
    FROM 
        chats c
    JOIN 
        channels ch ON c.channelId = ch.channelId
    WHERE 
        ch.affiliation IS NOT NULL
    GROUP BY 
        ch.affiliation,
        TO_DATE(c.timestamp)
    )
    SELECT 
    affiliation, 
    chat_date, 
    daily_active_users,
    ROUND(AVG(daily_active_users) OVER (
        PARTITION BY affiliation 
        ORDER BY chat_date 
        ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
    ), 2) AS 7_day_mau
    FROM 
    DailyActiveChatters
    ORDER BY 
    affiliation, 
    chat_date;
    """
    return spark.sql(query)

# %%
import plotly.express as px

# 1. Execute the query and convert to Pandas
df_x11 = x11().toPandas()

# 2. Generate the Time-Series Line Chart
fig = px.line(
    df_x11,
    x='chat_date',
    y='7_day_mau',          # Plotting the smoothed average, not the noisy daily metric
    color='affiliation',
    title='7-Day Moving Average: Daily Active Chatters by Agency',
    labels={
        'chat_date': 'Date',
        '7_day_mau': '7-Day Avg Unique Chatters',
        'affiliation': 'Agency'
    },
    template='plotly_dark',
    color_discrete_sequence=px.colors.qualitative.Vivid
)

# 3. Add a range slider for easy zooming across months/years
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(step="all")
        ])
    )
)

# 4. Fix compression: Increase overall height and adjust margins
fig.update_layout(
    hovermode="x unified",
    height=800,               # <--- INCREASES TOTAL CHART HEIGHT (Default is usually ~450-500)
    margin=dict(t=80, b=50),  # Ensures title and range slider have enough breathing room
    yaxis=dict(
        autorange=True,
        fixedrange=False      # Ensures the y-axis scales properly when zooming
    )
)

fig.show()

# %%
x11().show()
# Out:
# +-----------+----------+------------------+---------+
# |affiliation| chat_date|daily_active_users|7_day_mau|
# +-----------+----------+------------------+---------+
# |      .LIVE|2021-02-18|              1215|   1215.0|
# |      .LIVE|2021-02-19|              1695|   1455.0|
# |      .LIVE|2021-02-20|               457|  1122.33|
# |      .LIVE|2021-02-21|               210|   894.25|
# |      .LIVE|2021-02-22|               509|    817.2|
# |      .LIVE|2021-02-23|               916|   833.67|
# |      .LIVE|2021-02-24|              2520|  1074.57|
# |      .LIVE|2021-02-25|              1623|  1132.86|
# |      .LIVE|2021-02-26|              1106|  1048.71|
# |      .LIVE|2021-02-27|              2058|  1277.43|
# |      .LIVE|2021-02-28|              2250|  1568.86|
# |      .LIVE|2021-03-01|              1314|  1683.86|
# |      .LIVE|2021-03-02|              1510|  1768.71|
# |      .LIVE|2021-03-03|              1114|  1567.86|
# |      .LIVE|2021-03-04|              1157|  1501.29|
# |      .LIVE|2021-03-05|              1042|  1492.14|
# |      .LIVE|2021-03-06|              1711|  1442.57|
# |      .LIVE|2021-03-07|              1891|  1391.29|
# |      .LIVE|2021-03-08|              2167|  1513.14|
# |      .LIVE|2021-03-09|              1625|  1529.57|
# +-----------+----------+------------------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Advanced Aggregation: Identifying the Hype Peaks (Top 3 Peak BPM per Agency)
#
# Business Objective: Find out which 3 specific streams/moments generated the absolute fastest chat velocity (messages per minute / BPM) for each agency.
#
# Concepts: `DATE_TRUNC('minute', ...)`, **Nested Subqueries** with **Window Functions**

# %%
def x12():
    """ dxstrng """

    query = """ WITH MinuteAggregations AS (
        SELECT 
            ch.affiliation, 
            ch.englishName, 
            DATE_TRUNC('minute', c.timestamp) AS chat_minute, 
            COUNT(1) AS messages_per_minute
        FROM 
            chats c 
        JOIN 
            channels ch ON c.channelId = ch.channelId
        WHERE 
            ch.affiliation IS NOT NULL
        GROUP BY 
            ch.affiliation, 
            ch.englishName, 
            DATE_TRUNC('minute', c.timestamp)
    ),
    AgencyPeakVelocity AS (
        SELECT 
            affiliation, 
            englishName, 
            MAX(messages_per_minute) AS peak_bpm
        FROM 
            MinuteAggregations
        GROUP BY 
            affiliation, 
            englishName
    )
    SELECT 
        affiliation, 
        englishName, 
        peak_bpm
    FROM (
        SELECT 
            affiliation, 
            englishName, 
            peak_bpm,
            RANK() OVER (PARTITION BY affiliation ORDER BY peak_bpm DESC) as rnk
        FROM 
            AgencyPeakVelocity
    ) ranked_peaks
    WHERE 
        rnk <= 3
    ORDER BY 
        affiliation, 
        rnk;
    """

    return spark.sql(query)

# %%
# 1. Execute the query and convert to Pandas
df_x12 = x12().toPandas()

# 2. Create the Grouped Bar Chart
fig = px.bar(
    df_x12,
    x='affiliation',
    y='peak_bpm',
    color='affiliation',      # Groups the colors by agency
    text='englishName',       # Annotates the specific VTuber directly on the bar
    barmode='group',          # Places the 3 VTubers side-by-side per agency
    title='Hype Peaks: Top 3 Peak Chat Velocity (BPM) per Agency',
    labels={
        'affiliation': 'Agency',
        'peak_bpm': 'Peak Messages Per Minute (BPM)'
    },
    template='plotly_dark'
)

# 3. Enhance text readability and layout
fig.update_traces(
    textposition='outside',   # Pushes the name above the bar
    textangle=-45,            # Tilts the text so long names don't overlap
    cliponaxis=False          # Ensures text doesn't get cut off at the top of the chart
)

# 4. Clean up the UI
fig.update_layout(
    showlegend=False,         # Hide legend (redundant since x-axis has agency names)
    margin=dict(t=100),       # Give extra room at the top for the tilted text
    xaxis_title="VTuber Agency",
    yaxis_title="Peak BPM"
)

fig.show()

# %%
x12().show()
# Out:
# +-----------------+-------------------+--------+
# |      affiliation|        englishName|peak_bpm|
# +-----------------+-------------------+--------+
# |            .LIVE|       Kongou Iroha|    2024|
# |            .LIVE|    Kitakami Futaba|    1848|
# |            .LIVE|     Yaezawa Natori|    1600|
# |           774inc|    Hashiba Natsumi|    1239|
# |           774inc|         Suou Patra|    1190|
# |           774inc|       Inaba Haneru|    1136|
# |Aogiri Highschool|     Otodama Tamako|     409|
# |Aogiri Highschool|     Ishikari Akari|     285|
# |Aogiri Highschool|    Komaru Kurikoma|     273|
# |     Atelier Live|      Anya Pandaria|     560|
# |     Atelier Live|Artemis of the Blue|     498|
# |     Atelier Live|      Kani Kanizawa|     210|
# |           Axel-V|     Mizukura Canal|     250|
# |           Axel-V|         Akuma Saki|     198|
# |           Axel-V|      Suimitsu Momo|     110|
# |        Chukorara|        Hiseki Erio|     171|
# |        Chukorara|          Otome Oto|     138|
# |        Chukorara|       Komori Chiyu|     101|
# |    Cloud Horizon|       Linglan Lily|    1013|
# |    Cloud Horizon|     Kamiina Haruhi|     653|
# +-----------------+-------------------+--------+
# only showing top 20 rows
